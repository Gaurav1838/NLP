# %%
# List of common stopwords
stopwords = [
    "is", "am", "are", "was", "were", "the", "a", "an", "and",
    "or", "in", "on", "at", "to", "for", "of", "with", "by"
]

# Input sentence
text = input("Enter a sentence:\n")

# Split sentence into words
words = text.split()

# Remove stopwords
filtered_words = []
for word in words:
    if word.lower() not in stopwords:
        filtered_words.append(word)

# Output
print("\nAfter removing stopwords:")
print(filtered_words)
# Out:
# Enter a sentence:
# This is a simple program to remove stop words from a sentence
#
# After removing stopwords:
# ['This', 'simple', 'program', 'remove', 'stop', 'words', 'from', 'sentence']
